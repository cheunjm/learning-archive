# %%
import pandas as pd
from sas7bdat import SAS7BDAT
from collections import Counter

# %%
df = pd.read_sas('a16_20y_g20t22.sas7bdat', format='sas7bdat', encoding="utf-8")

# %%
df.head(5)
# Out:
#   SEX_TP_CD RECU_TO_DD DGRSLT_TP_CD FST_IPAT_DD IPAT_ARIV_PTH_TP_CD  \
# 0         1   20160115            1         NaN                   $
# 1         1   20160122            1         NaN                   $
# 2         1   20160106            1         NaN                   $
# 3         1   20160126            1         NaN                   $
# 4         2        NaN            5         NaN                   $
#
#           key         no  PAT_AGE  RECU_DDCNT  VST_DDCNT      yno recu_fr_dt  \
# 0   2505563.0   607637.0     65.0         1.0        1.0  58283.0 2016-01-15
# 1   2508252.0   607637.0     65.0         1.0        1.0  58283.0 2016-01-22
# 2   2473451.0   607637.0     65.0         1.0        1.0  19587.0 2016-01-06
# 3   4224195.0  1125310.0     72.0         1.0        1.0  26780.0 2016-01-26
# 4  50580006.0   988243.0     76.0         1.0        1.0  47511.0 2016-01-08
#
#   fst_ipat_dt recu_to_dt  no_cnt y_jong ORG_DF zip_sd  BED_GRADE
# ...

# %%
Counter(df['IPAT_ARIV_PTH_TP_CD'])
# Out:
# Counter({'$': 1741527,
#          '32': 100596,
#          '31': 10679,
#          '12': 837,
#          '22': 171,
#          '21': 676,
#          '11': 770})

# %%
Counter(df['fst_ipat_dt'])
# Out:
# Counter({NaT: 1744254,
#          Timestamp('2014-06-24 00:00:00'): 13,
#          Timestamp('2014-04-25 00:00:00'): 27,
#          Timestamp('2014-10-27 00:00:00'): 59,
#          Timestamp('2010-07-17 00:00:00'): 2,
#          Timestamp('2016-01-12 00:00:00'): 286,
#          Timestamp('2016-01-25 00:00:00'): 206,
#          Timestamp('2016-01-26 00:00:00'): 276,
#          Timestamp('2016-01-18 00:00:00'): 326,
#          Timestamp('2016-01-17 00:00:00'): 17,
#          Timestamp('2015-06-16 00:00:00'): 30,
#          Timestamp('2015-09-23 00:00:00'): 8,
#          Timestamp('2014-11-28 00:00:00'): 49,
#          Timestamp('2014-04-02 00:00:00'): 27,
#          Timestamp('2015-09-18 00:00:00'): 41,
#          Timestamp('2014-10-12 00:00:00'): 13,
#          Timestamp('2015-10-29 00:00:00'): 102,
#          Timestamp('2015-04-13 00:00:00'): 95,
#          Timestamp('2015-12-15 00:00:00'): 90,
#          Timestamp('2011-03-14 00:00:00'): 12,
# ...
